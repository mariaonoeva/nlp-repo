# %% [markdown]
# # WisperAI

# %%
import whisper

audio = "/Users/maria.onoeva/Desktop/PQ_text_to_speech/babushka_kino_f_amazon.wav"

model_turbo = whisper.load_model("turbo")

# %%
#model_large = whisper.load_model("large") сломала мне компик блин!!!

# %%
def speech_to_text(input_audio):
    output_text = model_turbo.transcribe(input_audio, language="ru", fp16=False)
    print(f"Text: {output_text["text"]}")

# %%
yandex_question = "/Users/maria.onoeva/Desktop/PQ_text_to_speech/babushka_kino_yandex.wav"
speech_to_text(yandex_question)
# Out:
# File /Users/maria.onoeva/Desktop/PQ_text_to_speech/babushka_kino_yandex.wav was transcribed.
# Text:  Бабушка ходила вчера в кино.

# %%
masha_info_seeking = "/Users/maria.onoeva/Desktop/audio/5_1_infoGlint.wav"
speech_to_text(masha_info_seeking)
# Out:
# File /Users/maria.onoeva/Desktop/audio/5_1_infoGlint.wav was transcribed.
# Text:  До нали у меня Глинтвейна!

# %%
audio1 = "/Users/maria.onoeva/Desktop/speech-to-text/F2_1_a.wav"
speech_to_text(audio1)
# Out:
# Text:  Разве Володя развесил утром белье?

# %%
audio2 = "/Users/maria.onoeva/Desktop/speech-to-text/E1_1_c.wav"
speech_to_text(audio2)
# Out:
# Text:  Не сложила ли Вероника вчера пазл?

# %%
audio3 = "/Users/maria.onoeva/Desktop/speech-to-text/E1_2_b.wav"
speech_to_text(audio3)
# Out:
# Text:  Миша зажег вечером свечку.
